# %% [markdown]
# ## 1-1-2 Matplotlib でグラフを描画する

# %%
import matplotlib.pyplot as plt
import math

# %%
xs1 =[0.0 , 2.5,5,7.5,10,12.5,15,17.5 , 20.0]
ys2 = [
    10000,  
    10765,  
    11593,  
    12488,  
    13459,  
    14509,  
    15643,  
    16867,  
    18188   
]
ys1= [
    10000, 
    10750, 
    11500, 
    12250, 
    13000, 
    13750, 
    14500, 
    15250, 
    16000  
]

plt.plot(xs1, ys1 , label = "Simple")
plt.plot(xs1, ys2 , label = "Compound")
plt.xlabel("Year")
plt.ylabel("Amount")
plt.legend()
plt.show()
